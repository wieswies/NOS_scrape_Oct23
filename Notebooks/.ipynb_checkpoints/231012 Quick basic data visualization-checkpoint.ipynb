# %%
from bs4 import BeautifulSoup
import requests
from PIL import Image
from io import BytesIO
import pandas as pd
import plotly.graph_objects as go
import plotly as px
import seaborn as sns
import itertools
import re
import time
from datetime import date, timedelta
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.colors as mcolors
from matplotlib.dates import MonthLocator, DateFormatter
import mplcursors

# %% [markdown]
# ## Dataset information
# ### NOS articles from October 4, 2022 up to October 4, 2023
# Including the following metadata:
#     Article ID
#     Link
#     Title
#     Date
#     Time
#     Category
#     Images
#     Paragraphs

# %%
article_df = pd.read_excel('NOS_articles_221004-231004_corrected.xlsx')

# %%
article_df = article_df.drop('Unnamed: 0', axis=1)

# %%
print(article_df.shape)
article_df.dtypes
# Out:
# (13387, 8)
# Article ID    float64
# Link           object
# Title          object
# Date           object
# Time           object
# Category       object
# Images         object
# Paragraphs     object
# dtype: object

# %% [markdown]
# ### Basic data manipulation

# %% [markdown]
# ##### Add complementary date values

# %%
article_df['Date'] = article_df['Date'].apply(pd.Timestamp)
article_df['Date'] = pd.to_datetime(article_df['Date'], format='%Y-%m-%d')
article_df['Month'] = article_df['Date'].dt.to_period('M')
article_df['Weekday'] = article_df['Date'].dt.weekday

# %% [markdown]
# ##### Convert data types

# %%
article_df['Date'] = pd.to_datetime(article_df['Date']).dt.date
article_df['Time'] = pd.to_datetime(article_df['Time'], format = '%H:%M:%S').dt.time

# %% [markdown]
# ##### Extract main category

# %%
nos_main_categories = [
    'Voorpagina',
    'Laatste nieuws',
    'Binnenland',
    'Buitenland',
    'Regionaal nieuws',
    'Politiek',
    'Economie',
    'Koningshuis',
    'Tech',
    'Cultuur & Media',
    'Opmerkelijk'
]

# %%
# Remove characters
article_df['Category'] = article_df['Category'].str.replace('\\', '', regex=True).str.replace("'", '', regex=True)

# Extract main category
article_df['Main category'] = article_df['Category'].apply(lambda x: list(main for main in nos_main_categories if main in x), None).apply(lambda x: ', '.join(map(str, x)))

# %%
# Check
article_df['Main category']
# Out:
# 0                    Buitenland
# 1                      Economie
# 2                    Buitenland
# 3                    Binnenland
# 4                    Buitenland
#                   ...
# 13382    Binnenland, Buitenland
# 13383                Binnenland
# 13384                Binnenland
# 13385                  Economie
# 13386                Buitenland
# Name: Main category, Length: 13387, dtype: object

# %% [markdown]
# ## Exploratory basic data visualization

# %%
article_counts_date = article_df.groupby('Date')['Link'].count().reset_index()

# %%
article_counts_date
# Out:
#            Date  Link
# 0    2022-10-04    50
# 1    2022-10-05    38
# 2    2022-10-06    53
# 3    2022-10-07    40
# 4    2022-10-08    26
# ..          ...   ...
# 360  2023-09-29    38
# 361  2023-09-30    23
# 362  2023-10-01    20
# 363  2023-10-02    43
# 364  2023-10-03    43
#
# [365 rows x 2 columns]

# %% [markdown]
# #### Timeline

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=article_counts_date['Date'],
    y=article_counts_date['Link'],
    mode='lines+markers',
    hovertemplate='%{x|%A, %B %d, %Y}<br>Articles: %{y}<extra></extra>',
    line=dict(shape='linear'),
    marker=dict(size=8),
))

fig.update_layout(
    title='NOS articles; Oct 4, 2022 - Oct 4, 2023',
    xaxis_title='Date',
    yaxis_title='Number of Articles',
    xaxis=dict(
        tickformat="%b %Y",  
        tickangle=45,  
    )
)

fig.show()

# %% [markdown]
# #### Per news category

# %%
article_df_catgraph = article_df.copy()
article_df_catgraph['str(Month)'] = article_df_catgraph['Month'].dt.strftime('%b %Y')

# %%
grouped_data = article_df_catgraph.groupby(['Date', 'Main category']).size().unstack().fillna(0)

# %%
cmap = plt.get_cmap('tab20', article_df_catgraph['Main category'].nunique())

plt.figure(figsize=(10, 6))

for i, category in enumerate(grouped_data.columns):
    plt.fill_between(grouped_data.index, 0, grouped_data[category], label=category, color=cmap(i), alpha = 0.4)

plt.xlabel('Month')
plt.ylabel('#Articles')
plt.title('Line Chart of Articles by Main Category')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# #### Summarized category overview

# %%
category_counts = article_df_catgraph.groupby('Main category')['Link'].count()

category_counts.sort_values(ascending=False)[:15]
# Out:
# Main category
# Buitenland                      4303
# Binnenland                      2685
# Regionaal nieuws                1971
# Economie                         926
# Politiek                         849
# Binnenland, Buitenland           486
# Cultuur & Media                  305
# Binnenland, Politiek             262
# Buitenland, Cultuur & Media      180
# Binnenland, Cultuur & Media      152
#                                  142
# Economie, Tech                   108
# Binnenland, Regionaal nieuws     106
# Binnenland, Economie             101
# Politiek, Economie                77
# Name: Link, dtype: int64

# %% [markdown]
# ### Focus on politics

# %%
article_df_pol = article_df[article_df['Category'].str.contains('Politiek', case=False, na=False)]

# %%
print(f'''
    The proportion of political articles in the dataset is {len(article_df_pol)} out of {len(article_df)}, 
    which equals {int(len(article_df_pol)/len(article_df)*100)}% of the dataset.
''')
# Out:
#     The proportion of political articles in the dataset is 1363 out of 13387,
#     which equals 10% of the dataset.

# %%
pol_counts = article_df_pol.groupby('Date')['Link'].count().reset_index()

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=pol_counts['Date'],
    y=pol_counts['Link'],
    mode='lines+markers',
    hovertemplate='%{x|%A, %B %d, %Y}<br>Articles: %{y}<extra></extra>',
    line=dict(shape='linear'),
    marker=dict(size=8),
))

fig.update_layout(
    title='NOS articles; Oct 4, 2022 - Oct 4, 2023',
    xaxis_title='Date',
    yaxis_title='Number of Articles',
    xaxis=dict(
        tickformat="%b %Y",  
        tickangle=45,  
    )
)

fig.show()
